# %% [markdown]
# ## setup

# %%
# suppress warnings
import warnings
warnings.simplefilter('ignore')

#import packages
import numpy as np
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt
import subprocess
from datetime import datetime


#local imports from opensoundscape
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram
from opensoundscape.ribbit import ribbit

# create big visuals
plt.rcParams['figure.figsize']=[15,8]
pd.set_option('display.precision', 2)

# %% [markdown]
# ## read in RIBBIT scores and basic cleaning

# %%
# folder with ribbit scores of interest
ribbit_folder = "ribbit_scores_2020_01_20"

#creates list of all cdv ribbit files to concatonate into one df of all ribbit scores
all_files = glob(ribbit_folder + "/*.csv")
ribbit_list = []

# reads in all ribbit scores to csv 
for filename in all_files: 
    df = pd.read_csv("./" + filename)
    ribbit_list.append(df)
    
rs_df = pd.concat(ribbit_list, axis=0, ignore_index=True) # translates list into dataframe 

rs_df = rs_df.rename(columns={"Unnamed: 0" : "file_path"})

# use file_path to create column with date and time of file 
rs_df['date'] = pd.to_datetime(test_df.file_path.str[-19:-4], format='%Y%m%d_%H%M%S', errors='coerce')

# add in manually determined files
tr_df = pd.read_csv("./training_data.csv")
rs_df = pd.merge(rs_df, tr_df, on=['pond', 'file_path'], how = "left")
# todo: add that if file starts with "Lcapito", Lcapito = 1

# %%
# Out:
#                                                file_path   score  time_stamp  \
# 0      /Volumes/Expansion/Frog Call Project/Calling D...  152.62       170.5
# 1      /Volumes/Expansion/Frog Call Project/Calling D...  134.04       242.5
# 2      /Volumes/Expansion/Frog Call Project/Calling D...  113.83       176.5
# 3      /Volumes/Expansion/Frog Call Project/Calling D...   98.98        87.5
# 4      /Volumes/Expansion/Frog Call Project/Calling D...   98.95       216.5
# ...                                                  ...     ...         ...
# 32647  /Volumes/Expansion/Frog Call Project/Calling D...   27.57       220.5
# 32648  /Volumes/Expansion/Frog Call Project/Calling D...   26.95        35.5
# 32649  /Volumes/Expansion/Frog Call Project/Calling D...   26.55        24.5
# 32650  /Volumes/Expansion/Frog Call Project/Calling D...   26.05        48.0
# 32651  /Volumes/Expansion/Frog Call Project/Calling D...   25.74       104.0
#
#        year  pond                date  Lcapito
# 0      2018   400 2018-02-16 23:24:00      NaN
# 1      2018   400 2018-02-12 20:20:00      NaN
# 2      2018   400 2018-04-19 01:09:00      NaN
# 3      2018   400 2018-04-17 22:08:00      NaN
# 4      2018   400 2018-02-11 19:19:00      NaN
# ...     ...   ...                 ...      ...
# 32647  2020   398 2020-03-09 00:40:00      NaN
# 32648  2020   398 2020-04-04 02:59:00      NaN
# 32649  2020   398 2020-05-04 01:20:00      NaN
# 32650  2020   398 2020-04-14 19:06:00      NaN
# 32651  2020   398 2020-04-03 02:58:00      NaN
#
# [32652 rows x 7 columns]

# %% [markdown]
# ## plotting ribbit scores

# %%
tr_df
# Out:
#                                             file_path  pond  Lcapito
# 0   /Volumes/Expansion/Frog Call Project/Calling D...   400        0
# 1   /Volumes/Expansion/Frog Call Project/Calling D...   400        1
# 2   /Volumes/Expansion/Frog Call Project/Calling D...   400        0
# 3   /Volumes/Expansion/Frog Call Project/Calling D...   400        0
# 4   /Volumes/Expansion/Frog Call Project/Calling D...   400        0
# 5   /Volumes/Expansion/Frog Call Project/Calling D...   400        1
# 6   /Volumes/Expansion/Frog Call Project/Calling D...   400        0
# 7   /Volumes/Expansion/Frog Call Project/Calling D...   400        0
# 8   /Volumes/Expansion/Frog Call Project/Calling D...   400        0
# 9   /Volumes/Expansion/Frog Call Project/Calling D...   400        0
# 10  /Volumes/Expansion/Frog Call Project/Calling D...   400        1
# 11  /Volumes/Expansion/Frog Call Project/Calling D...   398        0
# 12  /Volumes/Expansion/Frog Call Project/Calling D...   398        0
# 13  /Volumes/Expansion/Frog Call Project/Calling D...   398        0
# 14  /Volumes/Expansion/Frog Call Project/Calling D...   398        0
# 15  /Volumes/Expansion/Frog Call Project/Calling D...   398        0
# 16  /Volumes/Expansion/Frog Call Project/Calling D...   399        1
# 17  /Volumes/Expansion/Frog Call Project/Calling D...   399        1
# 18  /Volumes/Expansion/Frog Call Project/Calling D...   399        1
# 19  /Volumes/Expansion/Frog Call Project/Calling D...   400        1
# 20  /Volumes/Expansion/Frog Call Project/Calling D...   400        1
# 21  /Volumes/Expansion/Frog Call Project/Calling D...   400        1
# 22  /Volumes/Expansion/Frog Call Project/Calling D...   399        1
# 23  /Volumes/Expansion/Frog Call Project/Calling D...   399        1
# 24  /Volumes/Expansion/Frog Call Project/Calling D...   399        1

# %%
def plot_rs(pond_no = "all", year = "all"):
    
    plot_data = rs_df

    if pond_no != "all":
        plot_data = plot_data[plot_data['pond'] == pond_no]

    if year != "all":
        plot_data = plot_data[plot_data['year'] == year]

        
    
    fig, ax = plt.subplots()  # a figure with a single Axes
    ax.scatter(plot_data['date'],plot_data['score'])
    ax.hlines(y = [40], xmin = plot_data.date.min(), 
              xmax = plot_data.date.max(),
             colors = 'r', linestyles = '--')
    ax.set_xlabel('date')
    ax.set_ylabel('RIBBIT score') 
    ax.set_title('RIBBIT scores')
    ax.set_ylim(0,400)
    

plot_rs(pond_no = 398, year = 2021)
#plot_rs(399)
#plot_rs(400)
#plot_rs(401)
#plot_rs(402)
#plot_rs(403)

# %%
rs_df[rs_df["pond"] == 403][rs_df[rs_df["pond"] == 403]['score'] > 50]
# Out:
#                                                file_path   score  time_stamp  \
# 2226   /Volumes/Expansion/Frog Call Project/Calling D...  124.62         7.5
# 2227   /Volumes/Expansion/Frog Call Project/Calling D...  110.99        16.5
# 2228   /Volumes/Expansion/Frog Call Project/Calling D...  107.77       104.0
# 2229   /Volumes/Expansion/Frog Call Project/Calling D...   97.65       276.5
# 2230   /Volumes/Expansion/Frog Call Project/Calling D...   97.65       284.5
# ...                                                  ...     ...         ...
# 29598  /Volumes/Expansion/Frog Call Project/Calling D...   50.58       201.0
# 29599  /Volumes/Expansion/Frog Call Project/Calling D...   50.25       224.5
# 29600  /Volumes/Expansion/Frog Call Project/Calling D...   50.12        40.0
# 29601  /Volumes/Expansion/Frog Call Project/Calling D...   50.07        47.5
# 29602  /Volumes/Expansion/Frog Call Project/Calling D...   50.01        15.0
#
#        year  pond                date
# 2226   2019   403 2019-02-02 02:10:00
# 2227   2019   403 2018-12-11 01:32:00
# 2228   2019   403 2019-02-02 00:10:00
# 2229   2019   403 2019-03-02 02:34:00
# 2230   2019   403 2019-01-29 02:06:00
# ...     ...   ...                 ...
# 29598  2021   403 2021-03-05 18:38:00
# 29599  2021   403 2021-02-27 17:33:00
# 29600  2021   403 2021-02-21 23:28:00
# 29601  2021   403 2021-03-01 19:35:00
# 29602  2021   403 2021-02-28 20:34:00
#
# [744 rows x 6 columns]

# %%
#add pond and year columns - didnt' do this when first running RIBBIT for all years (should not have to use again)
#temp_file = all_files[29]
#temp_df = pd.read_csv(temp_file).rename(columns={"Unnamed: 0" : "file_path"}).drop("label", axis=1, errors = "ignore")
#temp_df['year'] = 2020
#temp_df['pond'] = 398
#temp_df.to_csv(temp_file, index = False)
#pd.read_csv(temp_file)
