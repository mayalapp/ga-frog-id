# %% [markdown]
# # Setup

# %% [markdown]
# ## Import packages and define settings

# %%
# suppress warnings
import warnings
warnings.simplefilter('ignore')

#import packages
import numpy as np
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt
import subprocess
from datetime import datetime
from plotnine import *
import os

pd.options.display.max_colwidth = 200


#local imports from opensoundscape
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram
from opensoundscape.ribbit import ribbit

# create big visuals
plt.rcParams['figure.figsize']=[15,8]
pd.set_option('display.precision', 2)

# %% [markdown]
# ## Useful functions

# %%
# Combine multiple ribbit score csv files into one csv file. Useful when you break the data into several groups to 
# run the model simultaneously on those groups and then want to recombine the data into one dataframe
# Inputs: 
# folder - folder with all of the ribbit score csv files that should be combined. 
#    csv files must have the exact same columns 
#    e.g. rs_folder = "./ribbit_scores_flshe/"
# delete_files - if True, delete the old csv files and only keep the combined file 
# Results: 
# creates new csv file with all of the ribbit scores in one csv file. deletes all of the individual files
# returns the concatonated ribbit score dataframe 

def combine_csvs(folder_path, new_csv_name = "combined_data.csv", delete_files = False): 
    files = glob(folder_path+ "*.csv") #create list of all csv files in rs_folder 
    df = pd.DataFrame()

    for fp in files: 
        if(os.path.exists(fp) and os.path.isfile(fp)): # check whether file exists or not
            temp_df = pd.read_csv(fp, index_col = 0) # read in ribbit scores
            df = pd.concat([df, temp_df]) # add it to the new dataframe 
            
            print(fp + " concatenated")
            if(delete_files): # delete old files
                os.remove(fp)
                print("file deleted")
        else:
            print(fp + " not found")

    df.to_csv(folder_path + new_csv_name) # save dataframe to csv file 
    
    return df


# calculate prescision/recall for a model 
# Inputs: 
# df - dataframe with ribbit scores and 
# cutoffs - list of cutoff values 
# Outputs: 
# accuracy - dataframe with precision and recall for the ribbit scores 
def calc_accuracy(df, cutoffs):    
    accuracy = pd.DataFrame()
    accuracy.index = list(cutoffs)
    accuracy['precision'] = ''
    accuracy['recall'] = ''

    for c in cutoffs: 
        accuracy['precision'][c] = len(df[(df['Lcapito']==1) & (df['score']>c)])/len(df[df['score']>c])*100
        accuracy['recall'][c] = len(df[(df['Lcapito'] == 1) & (df['score']>c)])/len(df[(df['Lcapito'] == 1)])*100

    accuracy = accuracy.astype(int)
    
    return accuracy




# get list of audio files with top ribbit scores
#
# input: 
# df - data frame with ribbit scores 
# n - number of files per group (e.g. n = 5 gets top 5 ribbit scores per group)
# min_score - minimum ribbit score needed for file to be included 
# (e.g. if you want all files above a ribbit score of 50, min_score = 50 and n = 999999999999)
# group_col - the name of the column with the labels grouping our files 
#            (e.g. "pond" for sandhills or "Site" for ichaway wetlands)
#             if group_col = "", just takes overall top scores 
# groups - list of labels of the different categories we want to split the data into - e.g. "range(398, 403)"" for sandhills ponds or "ich_wetlands" for ichaway wetlands
# t_unit - unit for how often we want the top scores (options: D, W, M, Y - day, week, month, year)
#
# out: 
# dataframe with top `n` files with ribbit score over `min_score` for each `groups` for every `t_unit` 
def get_top_rs(df, n = 5, min_score = 0.0, group_col = 'no_groups', groups = range(398, 403), t_unit = "Y", score_col = "score", time_stamp_col = "time_stamp"):
    
    rs_df = df[df[score_col] > min_score] # only keep files with scores above the minimum allowed ribbit score
    
    if group_col == 'no_groups': # if we don't want to group the data - just want overall top scores
        rs_df['no_groups'] = "0"
        groups = ["0"]

    rs_df = rs_df[rs_df[group_col].isin(groups)]
    rs_df['date_group'] = rs_df['date'].dt.to_period(t_unit)


    out_df = rs_df.sort_values(by=score_col,ascending=False).groupby(by = [group_col, 'date_group']).head(n).sort_values(by = [group_col, 'year', 'date_group'])


        # organize the df
    out_df['file_path'] = out_df['file_path'].str.slice(61) # simplify file path to not have beginning crap
    
    first_cols = ['Lcapito',group_col,'date_group', score_col, time_stamp_col, 'file_path']
    last_cols = [col for col in out_df.columns if (col not in first_cols)]
    out_df = out_df[first_cols+last_cols]
    out_df = out_df.drop(labels = ["Unnamed: 0"], axis = 1)
    
    if 'no_groups' in out_df.columns:
        out_df = out_df.drop(labels = ['no_groups'], axis = 1)
    #out_df = out_df.reindex(columns = ['Lcapito', group_col, 'date_group', score_col, time_stamp_col, 'file_path']) #order columns 

    
    return out_df

# %% [markdown]
# # FLSHE data

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Combine multiple ribbit score csv files

# %%
# Only need to run if you need to combine ribbit scores from multiple csv files  
# Useful if you broke up a model run into section to run it faster 
# WARNING: if delete_files = True this will delete individual files after combining them
# keep next 2 lines commented out unless running this chunk to avoid deleting files unintentionally 

# folder_path = "./ribbit_scores_flshe_20221206/" #*# path to folder containing the csv files you want to combine 
# rs_flshe = combine_csvs(folder_path, delete_files = True)

# %% [markdown]
# ### Set up file and folder paths for data import and cleaning

# %%
# file path to csv file with ribbit scores 
ribbit_scores_fp = "./ribbit_scores_flshe_20221206/ribbit_scores_combined.csv" #*#

# file path to csv file with manually verified data 
verified_data_fp = "../manually_verified_data/FLSHE_pond400.csv" #*#

# path to folder containing audio files 
audio_files_fp = '/Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/' #*#
# Note: if the folders within this folder are structured differently, you may need to edit the full file paths in the 
#       data cleaning section below (inicated with #*#)

# %% [markdown]
# ### Import and clean csv file with ribbit scores

# %%
# Import ribbit scores based on ribbit_scores_fp
rs_flshe = pd.read_csv(ribbit_scores_fp, index_col = 0)

# extract date from file path 
rs_flshe['date'] = pd.to_datetime(rs_flshe.index.str[-19:-4], format='%Y%m%d_%H%M%S', errors='coerce')

# %% [markdown]
# ### Import and clean manually verified data

# %%
# import manually verified data 
verified_flshe = pd.read_csv(verified_data_fp)[["File name", "Pond #", "L. capito", "gopher call time", "Date"]] # keeps only listed columns 

# rename columns for convenience
verified_flshe = verified_flshe.rename(columns = {"File name":"file_name", "Pond #":"logger", "L. capito":"Lcapito", "gopher call time":"call_time", "Date":"date"})

# make Lcapito categorical
verified_flshe.Lcapito = verified_flshe.Lcapito.astype("category")

# create year column based on date string
verified_flshe['year'] = verified_flshe.date.str[0:4]
verified_flshe.astype({"year":"int"})

# add .wav to file name if it is not included with the file name 
for i in verified_flshe.index:
    if verified_flshe["file_name"][i][-4:] != ".wav": 
        verified_flshe["file_name"][i] = verified_flshe["file_name"][i] + ".wav"
    
#*# create full file path from file names, year, and logger numbers #*# 
verified_flshe['file_path'] = audio_files_fp + 'FLSHE_' + \
    verified_flshe['year'].astype('string') + \
    '/FLSHE_' + verified_flshe['year'].astype('string') + '_' + verified_flshe['logger'].astype('string') + '/' + \
    verified_flshe['file_name'] #*#

# set file path as index 
verified_flshe = verified_flshe.set_index('file_path')

# %% [markdown]
# ### Merge ribbit scores to manually verified data

# %%
# merge with ribbit scores data file 
verified_flshe = verified_flshe.drop(columns = ["year", "date", "logger"]).merge(rs_flshe, left_index = True, right_index = True)
verified_flshe = verified_flshe.dropna(subset=['Lcapito']) # drop any rows with "NaN" for Lcapito - if left empty, etc.

# %% [markdown]
# ## EDA

# %%
# plot ribbit scores for all files 
df = verified_flshe

(ggplot(df, aes(x = range(0,len(df)), y = 'score', color = 'Lcapito'))+ 
       geom_point(alpha = 0.5)+ 
        labs(x  = "File number", y = "RIBBIT score", title = "RIBBIT scores")+ 
        theme_bw()+ 
        theme(axis_text_x = element_text(angle = 90)))
# Out:
# <ggplot: (338178165)>

# %%
# plot ribbit scores for all files by date 
df = verified_flshe

(ggplot(df, aes(x = 'date', y = 'score', color = 'Lcapito'))+ 
       geom_point(alpha = 0.5)+ 
        labs(x  = "Date", y = "RIBBIT score", title = "FLSHE: RIBBIT scores")+ 
        theme_bw()+ 
        theme(axis_text_x = element_text(angle = 45)))
# Out:
# <ggplot: (322775473)>

# %%
df = rs_flshe#verified_flshe
cutoff = 45
print("Total number of files: " + str(len(df)))
print("Number of files with RIBBIT score above cutoff: " + str(len(df[df['score']>cutoff])
))

print(calc_accuracy(verified_flshe, [cutoff]))


(ggplot(df)+
aes(x = 'score')+
geom_histogram(bins = 200)+ geom_vline(xintercept = cutoff, linetype = "dashed", color = "blue")+
labs(title = "FLSHE RIBBIT score histogram", x = "RIBBIT score", y = "Number of files")+ 
xlim(0,200)+
theme_bw())
# Out:
# Total number of files: 38770
# Number of files with RIBBIT score above cutoff: 6848
#     precision  recall
# 45         63      91
# <ggplot: (338429941)>

# %%
cutoffs = range(0, 200)
accuracy_flshe = calc_accuracy(verified_flshe, cutoffs)

(ggplot(accuracy_flshe, aes(x = 'precision', y = 'recall'))+ 
       geom_point()+ 
        labs(x  = "Precision", y = "Recall", title = "FLSHE (testing set): Model accuracy for various threshold values")+ 
        annotate("point", x = 63, y = 91, colour = "blue", size = 5) +
        ylim(30, 100)+
        xlim(0, 100) +
        theme_bw())
# Out:
# <ggplot: (330617585)>

# %%
# plot ribbit scores 
df = rs_flshe[rs_flshe['logger']==403]
(ggplot(df, aes(x = 'date', y = 'score'))+ 
       geom_point(alpha = 0.75)+ 
        labs(x  = "Date", y = "RIBBIT score", title = "FLSHE: RIBBIT scores")+ 
        theme_bw()+ 
         geom_hline(yintercept = 200, color = 'gray', linetype = 'dashed') + 
        theme(axis_text_x = element_text(angle = 45)))
# Out:
# <ggplot: (333992697)>

# %%
rs_flshe[rs_flshe['logger']==403].sort_values("score", ascending = False)
# Out:
#                                                                                                              score  \
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190417_020700.wav  777.50
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190416_220700.wav  581.94
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20170607_014200.wav  188.07
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210201_201000.wav  160.00
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2022/FLSHE_2022_403/TEST_20220128_180600.wav  141.16
# ...                                                                                                            ...
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20171020_025949.wav   22.41
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210904_025958.wav    9.62
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210405_025958.wav    7.42
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210404_025958.wav    7.41
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190216_192300.wav   -1.00
#
#                                                                                                             year  \
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190417_020700.wav  2019
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190416_220700.wav  2019
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20170607_014200.wav  2017
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210201_201000.wav  2021
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2022/FLSHE_2022_403/TEST_20220128_180600.wav  2022
# ...                                                                                                          ...
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20171020_025949.wav  2017
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210904_025958.wav  2021
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210405_025958.wav  2021
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210404_025958.wav  2021
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190216_192300.wav  2019
#
#                                                                                                             logger  \
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190417_020700.wav     403
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190416_220700.wav     403
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20170607_014200.wav     403
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210201_201000.wav     403
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2022/FLSHE_2022_403/TEST_20220128_180600.wav     403
# ...                                                                                                            ...
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20171020_025949.wav     403
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210904_025958.wav     403
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210405_025958.wav     403
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210404_025958.wav     403
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190216_192300.wav     403
#
#                                                                                                             time_stamp  \
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190417_020700.wav       190.5
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190416_220700.wav        10.0
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20170607_014200.wav       207.5
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210201_201000.wav       105.5
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2022/FLSHE_2022_403/TEST_20220128_180600.wav       139.0
# ...                                                                                                                ...
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20171020_025949.wav         2.5
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210904_025958.wav         0.0
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210405_025958.wav         0.0
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210404_025958.wav         0.0
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190216_192300.wav        -1.0
#
#                                                                                                                           date
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190417_020700.wav 2019-04-17 02:07:00
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190416_220700.wav 2019-04-16 22:07:00
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20170607_014200.wav 2017-06-07 01:42:00
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210201_201000.wav 2021-02-01 20:10:00
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2022/FLSHE_2022_403/TEST_20220128_180600.wav 2022-01-28 18:06:00
# ...                                                                                                                        ...
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_403/TEST_20171020_025949.wav 2017-10-20 02:59:49
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210904_025958.wav 2021-09-04 02:59:58
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210405_025958.wav 2021-04-05 02:59:58
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2021/FLSHE_2021_403/TEST_20210404_025958.wav 2021-04-04 02:59:58
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2019/FLSHE_2019_403/TEST_20190216_192300.wav 2019-02-16 19:23:00
#
# [6983 rows x 5 columns]

# %% [markdown]
# # Ichaway data

# %% [markdown]
# ## Data cleaning

# %%
# Only need to run if you need to combine ribbit scores from multiple csv files  
# Useful if you broke up a model run into section to run it faster 
# WARNING: if delete_files = True this will delete individual files after combining them
# keep next line commented out unless running this chunk to avoid deleting files unintentionally 
# rs_ich = combine_csvs("./ribbit_scores_ich_20221206/", delete_files = True)
# Out:
# ./ribbit_scores_ich_20221206/ribbit_scores_combined.csv concatenated
# file deleted

# %%
###

# %%
verified_ich
# Out:
#                                                                                                        site  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav    W03
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav    W03
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav    W03
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav    W03
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav    W03
# ...                                                                                                     ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav  W58
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav  W58
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav  W58
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav  W58
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav  W58
#
#                                                                                                        species  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav     NOCAP
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav     NOCAP
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav     NOCAP
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav     NOCAP
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav     NOCAP
# ...                                                                                                        ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav   LISPH
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav   LISPH
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav   LISPH
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav   LISPH
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav   PSCRU
#
#                                                                                                         NAAMP  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav        1
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav        1
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav        1
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav        1
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav        1
# ...                                                                                                       ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav      1
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav      1
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav      1
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav      1
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav      2
#
#                                                                                                               file_name  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav    20150513_005400
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav    20150512_235400
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav    20150512_225400
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav    20150512_215400
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav    20150512_205400
# ...                                                                                                                 ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav  20140310_231300
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav  20140310_221300
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav  20140310_211300
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav  20140310_201300
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav  20140310_191300
#
#                                                                                                        folder_date  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav        5-8-15
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav        5-8-15
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav        5-8-15
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav        5-8-15
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav        5-8-15
# ...                                                                                                            ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav     3-10-14
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav     3-10-14
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav     3-10-14
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav     3-10-14
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav     3-10-14
#
#                                                                                                        Lcapito  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav     False
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav     False
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav     False
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav     False
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav     False
# ...                                                                                                        ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav   False
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav   False
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav   False
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav   False
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav   False
#
#                                                                                                         score  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav    10.65
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav    10.67
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav     6.55
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav    24.63
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav    33.63
# ...                                                                                                       ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav  23.31
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav  43.87
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav  56.72
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav  19.34
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav  17.50
#
#                                                                                                         year  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav    2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav    2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav    2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav    2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav    2015
# ...                                                                                                      ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav  2014
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav  2014
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav  2014
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav  2014
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav  2014
#
#                                                                                                        logger  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav       9a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav       9a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav       9a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav       9a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav       9a
# ...                                                                                                       ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav    10a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav    10a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav    10a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav    10a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav    10a
#
#                                                                                                         time_stamp  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav          73.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav         287.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav         263.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav          71.5
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav          81.5
# ...                                                                                                            ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav       122.5
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav        65.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav       227.5
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav         2.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav       279.0
#
#                                                                                                                       date
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150513_005400.wav   2015-05-13 00:54:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_235400.wav   2015-05-12 23:54:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_225400.wav   2015-05-12 22:54:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_215400.wav   2015-05-12 21:54:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/9a/5-8-15/20150512_205400.wav   2015-05-12 20:54:00
# ...                                                                                                                    ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_231300.wav 2014-03-10 23:13:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_221300.wav 2014-03-10 22:13:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_211300.wav 2014-03-10 21:13:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_201300.wav 2014-03-10 20:13:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2014/10a/3-10-14/20140310_191300.wav 2014-03-10 19:13:00
#
# [5030 rows x 11 columns]

# %%
rs_ich = pd.read_csv("./ribbit_scores_ich_20221206/ribbit_scores_combined.csv", index_col = 0)
# extract date from file path 
rs_ich['date'] = pd.to_datetime(rs_ich.index.str[-19:-4], format='%Y%m%d_%H%M%S', errors='coerce')
# Out:
#                                                                                                          score  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150314_231500.wav   260.08
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150321_221900.wav  255.43
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150313_231400.wav   189.74
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150322_232000.wav  156.86
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/8a/3-19-15/20150319_221900.wav   147.25
# ...                                                                                                        ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/5a/2-23-15/20150224_200200.wav     0.85
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/4a/6-25-15/20150626_221600.wav     0.67
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150420_003900.wav     0.57
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150419_233900.wav     0.33
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/6-11-15/20150613_001200.wav     0.16
#
#                                                                                                         year  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150314_231500.wav   2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150321_221900.wav  2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150313_231400.wav   2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150322_232000.wav  2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/8a/3-19-15/20150319_221900.wav   2015
# ...                                                                                                      ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/5a/2-23-15/20150224_200200.wav   2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/4a/6-25-15/20150626_221600.wav   2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150420_003900.wav   2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150419_233900.wav   2015
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/6-11-15/20150613_001200.wav   2015
#
#                                                                                                        logger  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150314_231500.wav      7a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150321_221900.wav    10a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150313_231400.wav      7a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150322_232000.wav    10a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/8a/3-19-15/20150319_221900.wav      8a
# ...                                                                                                       ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/5a/2-23-15/20150224_200200.wav      5a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/4a/6-25-15/20150626_221600.wav      4a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150420_003900.wav      1a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150419_233900.wav      1a
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/6-11-15/20150613_001200.wav      1a
#
#                                                                                                         time_stamp  \
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150314_231500.wav        286.5
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150321_221900.wav       274.5
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150313_231400.wav        101.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150322_232000.wav        13.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/8a/3-19-15/20150319_221900.wav        297.5
# ...                                                                                                            ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/5a/2-23-15/20150224_200200.wav         91.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/4a/6-25-15/20150626_221600.wav         71.5
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150420_003900.wav        197.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150419_233900.wav        253.0
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/6-11-15/20150613_001200.wav         43.5
#
#                                                                                                                       date
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150314_231500.wav  2015-03-14 23:15:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150321_221900.wav 2015-03-21 22:19:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/7a/3-12-15/20150313_231400.wav  2015-03-13 23:14:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/10a/3-19-15/20150322_232000.wav 2015-03-22 23:20:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/8a/3-19-15/20150319_221900.wav  2015-03-19 22:19:00
# ...                                                                                                                    ...
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/5a/2-23-15/20150224_200200.wav  2015-02-24 20:02:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/4a/6-25-15/20150626_221600.wav  2015-06-26 22:16:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150420_003900.wav  2015-04-20 00:39:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/4-16-15/20150419_233900.wav  2015-04-19 23:39:00
# /Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/1a/6-11-15/20150613_001200.wav  2015-06-13 00:12:00
#
# [6853 rows x 5 columns]

# %%
# Only run this once! if you need to combine manually verified data files 
# Data must have the following columns: "Site", "Logger", "Sample Date", "Species", "NAAMP", "File ID"
folder_path = "../manually_verified_data/ichaway_verified_data/"
raw_ich = combine_csvs(folder_path)
# Out:
# ../manually_verified_data/ichaway_verified_data/ichaway_verified_data.csv concatenated
# ../manually_verified_data/ichaway_verified_data/ichaway_verified_data_2014.csv concatenated
# ../manually_verified_data/ichaway_verified_data/ichaway_verified_data_2015.csv concatenated

# %%
# import manually verified data
raw_ich = pd.read_csv("../manually_verified_data/ichaway_verified_data/ichaway_verified_data.csv")[["Site", "Logger", "Sample Date", "Species", "NAAMP", "File ID", "Start Date"]]

# rename columns for convenience
raw_ich = raw_ich.rename(columns = {"Site":"site", "Logger":"logger", "Sample Date":"date", "Species":"species", "File ID":"file_name", "Start Date":"folder_date"})
# create year column based on date string
raw_ich['year'] = raw_ich.date.astype(str).str[-4:]
raw_ich.astype({"year":"int"})


# create full file path from file names andd logger numbers 
raw_ich['folder_date'] = pd.to_datetime(raw_ich['folder_date'], format='%m/%d/%Y').dt.strftime('%-m-%-d-%y')
raw_ich['file_path'] = '/Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_' + raw_ich['year'].astype('string') + '/' + raw_ich['logger'].astype('string') + 'a/' + raw_ich['folder_date'] + '/' + raw_ich['file_name'] + '.wav'
# set file path as index 
raw_ich = raw_ich.set_index('file_path')

raw_ich['Lcapito'] = raw_ich['species'] == 'LICAP'
raw_ich['Lcapito'] = raw_ich['Lcapito'].astype('category')

verified_ich = raw_ich.sort_values(["file_path", "Lcapito"], ascending = False).groupby('file_path').head(1) 

# merge with ribbit scores
verified_ich = verified_ich.drop(columns = ["year", "date", "logger"]).merge(rs_ich, left_index = True, right_index = True)
verified_ich = verified_ich.dropna(subset=['Lcapito']) # drop any rows with "NaN" for Lcapito - if data was entered incorrectly, empty, etc. 

### TODO:  still losing some files after merging - why?? 

# these files were labeled incorrectly in the ichaway data - there are gopher frogs in them 
# logger 5a: 
#20150205_194700
#20150205_204700
#20150205_214700

# fix these mistakes
temp = '/Volumes/Expansion/Frog Call Project/Calling Data/ichaway/ichaway_2015/5a/2-2-15/20150205_'
incorrect_files =  [temp + '194700.wav', temp + '204700.wav', temp + '214700.wav']
verified_ich.loc[verified_ich.index.isin(incorrect_files),'Lcapito'] = True

# %%
# plot ribbit scores by date for single model
df = verified_ich[verified_ich['year']==2015].sort_values('Lcapito')#[verified_ich['date']<='2014-05-01']
(ggplot(df, aes(x = 'date', y = 'score', color = 'Lcapito'))+ 
       geom_point(alpha = 0.75)+ 
        labs(x  = "Date", y = "RIBBIT score", title = "Ichaway 2015: RIBBIT scores")+ 
        theme_bw()+ 
        ylim(0, 900) +
        xlim(pd.to_datetime('2015-03-01'), pd.to_datetime('2015-08-01')) +
        theme(axis_text_x = element_text(angle = 45)))
# Out:
# <ggplot: (324677593)>

# %%
# wetlands with high ribbit scores and gopher frog calls 
wetlands2014 = ['W15', 'W50','W43', 'W51', 'W46', 'W11', 'W42', 'W53']
wetlands2015 = ['W55', 'W15', 'W51', 'W53', 'W42', 'W46']
verified_ich[verified_ich.site.isin(wetlands2014)][verified_ich["year"]==2014].sort_values(['site','score'], ascending = False).groupby(['site']).head(10)[verified_ich['Lcapito']==True].site.unique()
verified_ich[verified_ich.site.isin(wetlands2015)][verified_ich["year"]==2015].sort_values(['site','score'], ascending = False).groupby(['site']).head(10)[verified_ich['Lcapito']==True].site.unique()
# Out:
# array(['W51', 'W46', 'W42', 'W15'], dtype=object)

# %%
# wetlands with gopher frog calls
print(verified_ich['site'][verified_ich['year']==2014][verified_ich['Lcapito']==1].unique())
print(verified_ich['site'][verified_ich['year']==2015][verified_ich['Lcapito']==1].unique())
# Out:
# ['W15' 'W50' 'W43' 'W51' 'W46' 'W11' 'W42' 'W53']
# ['W55' 'W15' 'W51' 'W53' 'W42' 'W46']

# %%
# plot ribbit scores 
df = verified_ich[verified_ich['year']==2014][verified_ich['site']=='W46'].sort_values('Lcapito')#[verified_ich['date']<='2014-05-01']
(ggplot(df, aes(x = 'date', y = 'score', color = 'Lcapito'))+ 
       geom_point(alpha = 0.75)+ 
        labs(x  = "Date", y = "RIBBIT score", title = "Wetland 46: RIBBIT scores")+ 
        theme_bw()+ 
        #ylim(0, 900) +
        #xlim(pd.to_datetime('2015-03-01'), pd.to_datetime('2015-08-01')) +
        theme(axis_text_x = element_text(angle = 45)))
# Out:
# <ggplot: (325731089)>

# %%
cutoffs = range(0, 400)
df = verified_ich#[verified_ich['year']==2014]
accuracy_ich = calc_accuracy(df, cutoffs)

(ggplot(accuracy_ich, aes(x = 'precision', y = 'recall'))+ 
       geom_point()+ 
        labs(x  = "Precision", y = "Recall", title = "Ichaway 2014 (testing set): Model accuracy for various threshold values")+ 
        #annotate("point", x = 75, y = 88, colour = "blue", size = 5) +
        ylim(0, 100) + 
        xlim(0, 100)+
        theme_bw())
# Out:
# <ggplot: (325190037)>

# %%
cutoffs = range(0, 400)
df = verified_ich[verified_ich['year']==2015]
accuracy_ich = calc_accuracy(df, cutoffs)

(ggplot(accuracy_ich, aes(x = 'precision', y = 'recall'))+ 
       geom_point()+ 
        labs(x  = "Precision", y = "Recall", title = "Ichaway 2015 (training set): Model accuracy for various threshold values")+ 
        #annotate("point", x = 75, y = 88, colour = "blue", size = 5) +
        ylim(0, 100) + 
        xlim(0, 100)+
        theme_bw())
# Out:
# <ggplot: (333434293)>
