# %%
# suppress warnings
import warnings
warnings.simplefilter('ignore')

#import packages
import numpy as np
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt
import subprocess
from datetime import datetime
from plotnine import *
import os


#local imports from opensoundscape
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram
from opensoundscape.ribbit import ribbit

# create big visuals
plt.rcParams['figure.figsize']=[15,8]
pd.set_option('display.precision', 2)

# %%
# Combine multiple ribbit score csv files into one csv file. Useful when you break the data into several groups to 
# run the model simultaneously on those groups and then want to recombine the data into one dataframe
# Inputs: 
# rs_folder - folder with all of the ribbit score csv files that should be combined. 
#    csv files must have the exact same columns 
# delete_files - if True, delete the old csv files and only keep the combined file 
# Results: 
# creates new csv file with all of the ribbit scores in one csv file. deletes all of the individual files
# returns the concatonated ribbit score dataframe 

def combine_rs(rs_folder, delete_files = False): 
    rs_files = glob(rs_folder + ".csv") #create list of all  
    df = pd.DataFrame()

    # first check whether file exists or not
    for fp in rs_files: 
        if(os.path.exists(fp) and os.path.isfile(fp)):
            temp_df = pd.read_csv(fp, index_col = 0) # read in ribbit scores
            df = pd.concat([df, temp_df])
            
            if(delete_files):
                os.remove(fp)
                print("file deleted")
        else:
            print("file not found")

    df.to_csv(rs_folder + "ribbit_scores.csv")
    
    return df
# Out:
# file deleted
# file deleted
# file deleted
# file deleted
# file deleted
# file deleted

# %%
df.to_csv("./ribbit_scores_flshe_test/ribbit_scores.csv")

# %%
df
# Out:
#                                                      score  year  logger  \
# /Volumes/Expansion/Frog Call Project/Calling Da...  229.56  2018     402
# /Volumes/Expansion/Frog Call Project/Calling Da...  216.16  2018     400
# /Volumes/Expansion/Frog Call Project/Calling Da...  208.99  2018     400
# /Volumes/Expansion/Frog Call Project/Calling Da...  192.41  2018     402
# /Volumes/Expansion/Frog Call Project/Calling Da...  187.63  2018     400
# ...                                                    ...   ...     ...
# /Volumes/Expansion/Frog Call Project/Calling Da...   10.10  2017     401
# /Volumes/Expansion/Frog Call Project/Calling Da...    9.58  2017     398
# /Volumes/Expansion/Frog Call Project/Calling Da...    9.34  2017     401
# /Volumes/Expansion/Frog Call Project/Calling Da...    9.11  2017     402
# /Volumes/Expansion/Frog Call Project/Calling Da...    8.59  2017     400
#
#                                                     time_stamp
# /Volumes/Expansion/Frog Call Project/Calling Da...        97.5
# /Volumes/Expansion/Frog Call Project/Calling Da...       158.0
# /Volumes/Expansion/Frog Call Project/Calling Da...       134.0
# /Volumes/Expansion/Frog Call Project/Calling Da...        32.0
# /Volumes/Expansion/Frog Call Project/Calling Da...       189.0
# ...                                                        ...
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.5
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.0
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.0
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.0
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.5
#
# [38770 rows x 4 columns]

# %%
# list of file paths where ribbit scores are saved. 
# If the model was run once with all of the data, this will be a single file path. 
# If the data was run in several chunks simultaneously, this will be a file path for each set of data
rs_fp = ["./ribbit_scores_flshe/ribbit_scores_2017.csv"]

sa_flshe_df = pd.read_csv(rs_fp, index_col = 0) # read in ribbit scores
sa_flshe_df['date'] = pd.to_datetime(sa_flshe_df.index.str[-19:-4], format='%Y%m%d_%H%M%S', errors='coerce') #extract date from file path
sa_flshe_df
#sa_pulse_df['date']=pd.to_datetime(sa_pulse_df['date'])
# Out:
#                                                      score  year  logger  \
# /Volumes/Expansion/Frog Call Project/Calling Da...  546.87  2017     400
# /Volumes/Expansion/Frog Call Project/Calling Da...  450.13  2017     400
# /Volumes/Expansion/Frog Call Project/Calling Da...  442.50  2017     400
# /Volumes/Expansion/Frog Call Project/Calling Da...  412.17  2017     400
# /Volumes/Expansion/Frog Call Project/Calling Da...  388.02  2017     400
# ...                                                    ...   ...     ...
# /Volumes/Expansion/Frog Call Project/Calling Da...   10.10  2017     401
# /Volumes/Expansion/Frog Call Project/Calling Da...    9.58  2017     398
# /Volumes/Expansion/Frog Call Project/Calling Da...    9.34  2017     401
# /Volumes/Expansion/Frog Call Project/Calling Da...    9.11  2017     402
# /Volumes/Expansion/Frog Call Project/Calling Da...    8.59  2017     400
#
#                                                     time_stamp  \
# /Volumes/Expansion/Frog Call Project/Calling Da...       286.0
# /Volumes/Expansion/Frog Call Project/Calling Da...       273.0
# /Volumes/Expansion/Frog Call Project/Calling Da...        61.5
# /Volumes/Expansion/Frog Call Project/Calling Da...       245.5
# /Volumes/Expansion/Frog Call Project/Calling Da...        49.5
# ...                                                        ...
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.5
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.0
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.0
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.0
# /Volumes/Expansion/Frog Call Project/Calling Da...         0.5
#
#                                                                   date
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-02-13 21:21:00
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-02-13 23:21:00
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-02-11 23:19:00
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-02-13 20:21:00
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-02-12 21:20:00
# ...                                                                ...
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-02-23 00:33:58
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-06-19 20:51:58
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-01-27 21:10:58
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-02-23 00:33:58
# /Volumes/Expansion/Frog Call Project/Calling Da... 2017-02-22 23:33:58
#
# [9862 rows x 5 columns]

# %%
sa_flshe_df.index
# Out:
# Index(['/Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_398/TEST_0+1_20161031_174700.wav',
#        '/Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_398/TEST_0+1_20161031_184700.wav',
#        '/Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_398/TEST_0+1_20170104_174500.wav'],
#       dtype='object')
