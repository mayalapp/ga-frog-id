# %%
# suppress warnings
import warnings
warnings.simplefilter('ignore')

#import packages
import numpy as np
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt
import subprocess
from datetime import datetime
from plotnine import *
import os

pd.options.display.max_colwidth = 200


#local imports from opensoundscape
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram
from opensoundscape.ribbit import ribbit

# create big visuals
plt.rcParams['figure.figsize']=[15,8]
pd.set_option('display.precision', 2)

# %%
# Combine multiple ribbit score csv files into one csv file. Useful when you break the data into several groups to 
# run the model simultaneously on those groups and then want to recombine the data into one dataframe
# Inputs: 
# rs_folder - folder with all of the ribbit score csv files that should be combined. 
#    csv files must have the exact same columns 
#    e.g. rs_folder = "./ribbit_scores_flshe/"
# delete_files - if True, delete the old csv files and only keep the combined file 
# Results: 
# creates new csv file with all of the ribbit scores in one csv file. deletes all of the individual files
# returns the concatonated ribbit score dataframe 

def combine_rs(rs_folder, delete_files = False): 
    rs_files = glob(rs_folder+ "*.csv") #create list of all csv files in rs_folder 
    df = pd.DataFrame()

    for fp in rs_files: 
        if(os.path.exists(fp) and os.path.isfile(fp)): # check whether file exists or not
            temp_df = pd.read_csv(fp, index_col = 0) # read in ribbit scores
            df = pd.concat([df, temp_df]) # add it to the new dataframe 
            
            print(fp + " concatenated")
            if(delete_files): # delete old files
                os.remove(fp)
                print("file deleted")
        else:
            print(fp + " not found")

    df.to_csv(rs_folder + "ribbit_scores_combined.csv") # save dataframe to csv file 
    
    return df

# %% [markdown]
# # FLSHE data

# %% [markdown]
# ## Data cleaning

# %%
# Only need to run once! 
# combine flshe ribbit scores into one file 
rs_flshe = combine_rs("./ribbit_scores_flshe_20221206/", delete_files = True)
# Out:
# ./ribbit_scores_flshe_20221206/ribbit_scores_2018.csv concatenated
# file deleted
# ./ribbit_scores_flshe_20221206/ribbit_scores_2019.csv concatenated
# file deleted
# ./ribbit_scores_flshe_20221206/ribbit_scores_2021.csv concatenated
# file deleted
# ./ribbit_scores_flshe_20221206/ribbit_scores_2020.csv concatenated
# file deleted
# ./ribbit_scores_flshe_20221206/ribbit_scores_2022.csv concatenated
# file deleted
# ./ribbit_scores_flshe_20221206/ribbit_scores_2017.csv concatenated
# file deleted

# %%
# extract date from file path 
rs_flshe['date'] = pd.to_datetime(rs_flshe.index.str[-19:-4], format='%Y%m%d_%H%M%S', errors='coerce')

# %%
# import manually verified data 
verified_flshe = pd.read_csv("../manually_verified_data/FLSHE_pond400.csv")[["File name", "Pond #", "L. capito", "gopher call time", "Date"]]
# rename columns for convenience
verified_flshe = verified_flshe.rename(columns = {"File name":"file_name", "Pond #":"logger", "L. capito":"Lcapito", "gopher call time":"call_time", "Date":"date"})
# create year column based on date string
verified_flshe['year'] = verified_flshe.date.str[0:4]
verified_flshe.astype({"year":"int"})

# add .wav to file name if it is not included with the file name 
for i in verified_flshe.index:
    if verified_flshe["file_name"][i][-4:] != ".wav": 
        verified_flshe["file_name"][i] = verified_flshe["file_name"][i] + ".wav"
    
# create full file path from file names andd logger numbers 
verified_flshe['file_path'] = '/Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_' + verified_flshe['year'].astype('string') + '/FLSHE_' + verified_flshe['year'].astype('string') + '_' + verified_flshe['logger'].astype('string') + '/' + verified_flshe['file_name']
# set file path as index 
verified_flshe = verified_flshe.set_index('file_path')

# merge with ribbit scores
#verified_flshe = verified_flshe.merge(rs_flshe, left_on = "file_path", right_index = True)
verified_flshe = verified_flshe.drop(columns = ["year", "date", "logger"]).merge(rs_flshe, left_index = True, right_index = True)
verified_flshe = verified_flshe.dropna(subset=['Lcapito']) # drop any rows with "NaN" for Lcapito - if data was entered incorrectly, empty, etc.

# %%
# calculate prescision/recall for a model 

def calc_accuracy(df, cutoffs):    
    accuracy = pd.DataFrame()
    accuracy.index = list(cutoffs)
    accuracy['precision'] = ''
    accuracy['recall'] = ''

    for c in cutoffs: 
        accuracy['precision'][c] = len(df[(df['Lcapito']==1) & (df[score_col]>c)])/len(df[df[score_col]>c])*100
        accuracy['recall'][c] = len(df[(df['Lcapito'] == 1) & (df[score_col]>c)])/len(df[(df['Lcapito'] == 1)])*100

    accuracy = accuracy.astype(int)
    return accuracy

# %%
# plot ribbit scores by date for single model
df = verified_flshe
(ggplot(df, aes(x = range(0,len(verified_flshe)), y = 'score', color = 'Lcapito', alpha = 'Lcapito'))+ 
       geom_point()+ 
        labs(x  = "File number", y = "RIBBIT score", title = "RIBBIT scores")+ 
        theme_bw()+ 
        theme(axis_text_x = element_text(angle = 90)))
# Out:
# <ggplot: (323377393)>

# %%
# plot ribbit scores by date for single model
df = verified_flshe[verified_flshe["year"] == 2022]
(ggplot(df, aes(x = 'date', y = 'score', color = 'Lcapito', alpha = 'Lcapito'))+ 
       geom_point()+ 
        labs(x  = "Date", y = "RIBBIT score", title = "RIBBIT scores")+ 
        theme_bw()+ 
        theme(axis_text_x = element_text(angle = 90)))
# Out:
# <ggplot: (324437521)>

# %%
cutoff = 45
print("Total number of files: " + str(len(verified_flshe)))
print("Number of files with RIBBIT score above cutoff: " + str(len(verified_flshe[verified_flshe['score']>cutoff])
))

print(calc_accuracy(verified_flshe, [45]))


(ggplot(verified_flshe)+
aes(x = 'score')+
geom_histogram(bins = 40)+ geom_vline(xintercept = cutoff, linetype = "dashed", color = "blue")+
labs(title = "", x = "RIBBIT score", y = "Number of files")+ 
theme_bw())
# Out:
# Total number of files: 272
# Number of files with RIBBIT score above cutoff: 113
#     precision  recall
# 45         63      91
# <ggplot: (324025549)>

# %%
cutoffs = range(0, 100)
accuracy_flshe = calc_accuracy(verified_flshe, cutoffs)

(ggplot(accuracy_flshe, aes(x = 'precision', y = 'recall'))+ 
       geom_point()+ 
        labs(x  = "Precision", y = "Recall", title = "Model accuracy")+ 
        annotate("point", x = 63, y = 91, colour = "blue", size = 5) +
        theme_bw())
# Out:
# <ggplot: (317670437)>

# %%
# Out:
#     precision  recall
# 45         63      91

# %%
# Out:
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2018/FLSHE_2018_402/TEST_0+1_20180320_194900.wav        402
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2018/FLSHE_2018_400/TEST_0+1_20180212_202000.wav        400
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2018/FLSHE_2018_400/TEST_0+1_20180216_232400.wav        400
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2018/FLSHE_2018_402/TEST_0+1_20180320_224900.wav        402
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2018/FLSHE_2018_400/TEST_0+1_20180209_211700.wav        400
#                                                                                                                      ...
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_401/TEST_0+1_20170223_003358.wav        401
# /Volumes/Expansion/Frog Call Project/Calling Data/FLSHE/FLSHE_2017/FLSHE_2017_398/TEST_0+1_20170619_205158.wav        398
# ...

# %% [markdown]
# # Ichaway data

# %% [markdown]
# ## Data cleaning

# %%
# combine ichaway ribbit scores into one file 
rs_ich = combine_rs("./ribbit_scores_ich_20221206/")
# Out:
# ./ribbit_scores_flshe_20221206/ribbit_scores_2018.csv concatenated
# ./ribbit_scores_flshe_20221206/ribbit_scores_2019.csv concatenated
# ./ribbit_scores_flshe_20221206/ribbit_scores_2021.csv concatenated
# ./ribbit_scores_flshe_20221206/ribbit_scores_2020.csv concatenated
# ./ribbit_scores_flshe_20221206/ribbit_scores_2022.csv concatenated
# ./ribbit_scores_flshe_20221206/ribbit_scores_2017.csv concatenated
# ./ribbit_scores_ich_20221206/ribbit_scores_log4-6.csv concatenated
# ./ribbit_scores_ich_20221206/ribbit_scores_log8-10.csv concatenated
# ./ribbit_scores_ich_20221206/ribbit_scores_log1-3.csv concatenated
# ./ribbit_scores_ich_20221206/ribbit_scores_log7.csv concatenated

# %%
# extract date from file path 
rs_ich['date'] = pd.to_datetime(rs_ich.index.str[-19:-4], format='%Y%m%d_%H%M%S', errors='coerce')
