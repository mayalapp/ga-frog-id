# %% [markdown]
# ## setup

# %%
# suppress warnings
import warnings
warnings.simplefilter('ignore')

#import packages
import numpy as np
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt
import subprocess
from datetime import datetime
from plotnine import *


#local imports from opensoundscape
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram
from opensoundscape.ribbit import ribbit

# create big visuals
plt.rcParams['figure.figsize']=[15,8]
pd.set_option('display.precision', 2)

# %% [markdown]
# ## read in RIBBIT scores and basic cleaning

# %%
def read_ribbit_scores(ribbit_folder):  

    #creates list of all csv ribbit files to concatonate into one df of all ribbit scores
    all_files = glob(ribbit_folder + "/*.csv")
    ribbit_list = []

    # reads in all ribbit scores to csv 
    for filename in all_files: 
        df = pd.read_csv("./" + filename)
        ribbit_list.append(df)

    rs_df = pd.DataFrame()
    rs_df = pd.concat(ribbit_list, axis=0, ignore_index=True) # translates list into dataframe 

    rs_df = rs_df.rename(columns={"Unnamed: 0" : "file_path"})
    
    # use file_path to create column with date and time of file 
    rs_df['date'] = pd.to_datetime(rs_df.file_path.str[-19:-4], format='%Y%m%d_%H%M%S', errors='coerce')

    return rs_df
    
# read ribbit scores for FLSH
rs_df = read_ribbit_scores("ribbit_scores_2022_01_21")


# add in manually determined files (files people listened to and recorded what frogs were heard)
tr_df = pd.read_csv("./training_data.csv")
rs_df = pd.merge(rs_df, tr_df, on=['pond', 'file_path'], how = "left")
rs_df = rs_df.drop_duplicates() # TODO: remove duplicates #TODO: why duplicates? file with all scores? 

# todo: add that if file starts with "Lcapito", Lcapito = 1


# read ribbit scores for ichaway
ich_df = read_ribbit_scores("ribbit_scores_ichaway")
ich_verified_df = pd.read_csv("./ichaway_verified_data_2015.csv")

## create dataframe with Lcapito presence/abscence for each file 
# create column with unique file path for each audio file (there are multiple rows for some files - one for each frog observed in that file)
ich_verified_df['file_path']='/Volumes/Expansion/Frog Call Project/Calling Data/Frog Calls/ichaway_2015/' + ich_verified_df['Logger'].astype('string') + 'a/' + ich_verified_df['File ID'] + '.wav'
# add column with 1/0 for if the observation is of a Lcapito
ich_verified_df['Lcapito'] = ich_verified_df['Species'] == 'LICAP'
ich_verified_df['Lcapito'] = ich_verified_df['Lcapito'].astype('int')
# group one row per audio file with 1/0 for presence/abscence fo Lcapito
ich_tr_df = ich_verified_df.groupby('file_path').agg(Lcapito = ('Lcapito', 'max'))

ich_df = pd.merge(ich_df, ich_tr_df, on=['file_path'], how = "left")
ich_df = ich_df.drop_duplicates() # remove duplicates #TODO: why duplicates? file with all scores? 

# make dataframe with only files that have been maunally verified 
ich_tr_df = ich_df.dropna()

# %%
# Read in ichaway files 

## Read in verified files - right now this is with signal band [300-1000], noise band [150,200][1200,1600], clip duration = 1.5 s
ich_verified_files_df = pd.read_csv("./ribbit_scores_ichaway_verified_files/ichaway_verified_files_ribbit_scores.csv")
ich_verified_files_df['date']=pd.to_datetime(ich_verified_files_df['date'])


# read in SA files
sa_pulse_df = pd.read_csv("./ribbit_scores_pulse_rate_range/ribbit_scores2.csv")
sa_pulse_df['date']=pd.to_datetime(sa_pulse_df['date'])


# read in SA files
sa_noise_df = pd.read_csv("./ribbit_scores_noise_bands/ribbit_scores1.csv")
sa_noise_df['date']=pd.to_datetime(sa_noise_df['date'])

# read in SA files
sa_duration_df = pd.read_csv("./ribbit_scores_clip_duration/ribbit_scores1.csv")
sa_duration_df['date']=pd.to_datetime(sa_duration_df['date'])

# read in SA files
sa_signal_df = pd.read_csv("./ribbit_scores_signal_band/ribbit_scores2.csv")
sa_signal_df['date']=pd.to_datetime(sa_signal_df['date'])

# read in SA files
sa_window_df = pd.read_csv("./ribbit_scores_window_samples_base/ribbit_scores1.csv")
sa_window_df['date']=pd.to_datetime(sa_window_df['date'])

# read in SA files - this has noise band [1100,1200] instead of base noise band
sa_window_df2 = pd.read_csv("./ribbit_scores_window_samples/ribbit_scores1.csv")
sa_window_df2['date']=pd.to_datetime(sa_window_df['date'])
#### !!!!!!!! looks like somehow the Lcapito labels may have gotten mixed up? need to check on this !!!!!!!!!!!!!! 

# read in SA files
sa_optimal_guess_df = pd.read_csv("./ribbit_scores_optimal_guess/ribbit_scores0.csv")
sa_optimal_guess_df['date']=pd.to_datetime(sa_optimal_guess_df['date'])


# read in SA files
sa_optimal_guess_df2 = pd.read_csv("./ribbit_scores_optimal_guess_ws400/ribbit_scores0.csv")
sa_optimal_guess_df2['date']=pd.to_datetime(sa_optimal_guess_df2['date'])



# these files were labeled incorrectly in the ichaway data - there are gopher frogs in them 
# logger 5a: 
#20150205_194700
#20150205_204700
#20150205_214700

# fix these mistakes
temp = '/Volumes/Expansion/Frog Call Project/Calling Data/Frog Calls/ichaway_2015/5a/20150205_'
incorrect_files =  [temp + '194700.wav', temp + '204700.wav', temp + '214700.wav']
sa_pulse_df.loc[sa_pulse_df['file_path'].isin(incorrect_files),'Lcapito'] = 1
sa_noise_df.loc[sa_noise_df['file_path'].isin(incorrect_files),'Lcapito'] = 1
sa_duration_df.loc[sa_duration_df['file_path'].isin(incorrect_files),'Lcapito'] = 1
sa_signal_df.loc[sa_signal_df['file_path'].isin(incorrect_files),'Lcapito'] = 1
sa_window_df.loc[sa_window_df['file_path'].isin(incorrect_files),'Lcapito'] = 1
sa_window_df2.loc[sa_window_df2['file_path'].isin(incorrect_files),'Lcapito'] = 1
sa_optimal_guess_df.loc[sa_optimal_guess_df['file_path'].isin(incorrect_files),'Lcapito'] = 1
sa_optimal_guess_df2.loc[sa_optimal_guess_df2['file_path'].isin(incorrect_files),'Lcapito'] = 1

ich_tr_df.loc[ich_tr_df['file_path'].isin(incorrect_files),'Lcapito'] = 1
ich_verified_files_df.loc[ich_verified_files_df['file_path'].isin(incorrect_files),'Lcapito'] = 1

# make 'Lcapito' columns categories not numerics
sa_pulse_df['Lcapito'] = sa_pulse_df['Lcapito'].astype('category')
sa_noise_df['Lcapito'] = sa_noise_df['Lcapito'].astype('category')
sa_duration_df['Lcapito'] = sa_duration_df['Lcapito'].astype('category')
sa_signal_df['Lcapito'] = sa_signal_df['Lcapito'].astype('category')
sa_window_df['Lcapito'] = sa_window_df['Lcapito'].astype('category')
sa_window_df2['Lcapito'] = sa_window_df2['Lcapito'].astype('category')
sa_optimal_guess_df['Lcapito'] = sa_optimal_guess_df['Lcapito'].astype('category')
sa_optimal_guess_df2['Lcapito'] = sa_optimal_guess_df2['Lcapito'].astype('category')

# create dataframe with base data from SA 
sa_base_df = sa_pulse_df.drop(columns = ['time_stamp0', 'score0', 'time_stamp1','score1']).rename(columns={'score2':'score', 'time_stamp2':'time_stamp'})

# %%
print("Number of verified files in Ichaway data: " + str(len(sa_noise_df)))
print("Number of gopher frog observations in verified data: " + str(len(sa_noise_df[sa_noise_df['Lcapito'] == 1])))

# save list of the files that have been listened to at ichaway
#temp = ich_tr_df.drop(columns = ['score', 'time_stamp'])
#temp.to_csv('ich_verified_files.csv')
# Out:
# Number of verified files in Ichaway data: 2564
# Number of gopher frog observations in verified data: 56

# %%
# add Site to RIBBIT score dataframes
ich_verified_df["file_path"] = "/Volumes/Expansion/Frog Call Project/Calling Data/Frog Calls/ichaway_2015/" + ich_verified_df["Logger"].astype(str) + "a/" + ich_verified_df['File ID'] + ".wav"
ich_verified_df
sa_noise_df = pd.merge(sa_noise_df, ich_verified_df[["Site", "file_path"]].drop_duplicates(), on=['file_path'], how = "left")
#ich_verified_df[["Site", "file_path"]]

ich_wetlands = sa_noise_df["Site"].unique()

# %% [markdown]
# ## Senitivity analysis

# %%
# plot ribbit scores by date for single model


#window: score0; noise: score0; optimal_guess: score0; pulse: score2 (base) 
df = sa_noise_df 
score_col = 'score0'

(ggplot(df, aes(x = 'date', y = score_col, color = 'Lcapito', alpha = 'Lcapito'))+ 
       geom_point()+ 
        labs(x  = "Date", y = "RIBBIT score", title = "RIBBIT scores")+ 
        theme_bw()+ 
        theme(axis_text_x = element_text(angle = 90)))

# %%
# Out:
# array(['W42', 'W51', 'W15', 'W46', 'W40', 'W04', 'W53', 'W29', 'W03',
#        'W41', 'W35', 'W52', 'W58', 'W32', 'W55', 'W00', 'W96', 'W43',
#        'W68', 'W02', 'W37', 'W28', 'W36', 'W26', 'W27', 'W39', 'W11',
#        'W21', 'W01', 'W50'], dtype=object)

# %%
# get top 10 RIBBIT scores for each wetland
n = 5 # number of files per wetland 
temp0 = get_top_rs(sa_noise_df, n = n*30, groups = ich_wetlands, t_unit = 'Y', score_col = 'score0', time_stamp_col = 'time_stamp0')
temp1 = get_top_rs(sa_noise_df, n = n, group_col = "Site", groups = ich_wetlands, t_unit = 'Y', score_col = 'score0', time_stamp_col = 'time_stamp0')

print('Overall number of files: ' + str(len(temp0)))
print('Overall recall: ' + str(len(temp0[temp0['Lcapito']==1])))
print('Total number of files with 10 files per wetland: ' + str(len(temp1)))
print('By wetland recall: ' + str(len(temp1[temp1['Lcapito']==1])))
# Out:
# Overall number of files: 300
# Overall recall: 43
# Total number of files with 10 files per wetland: 300
# By wetland recall: 32

# %%
print(len(sa_noise_df))
# Out:
# 2564

# %%
# plot ribbit scores by date for single model


#window: score0; noise: score0; optimal_guess: score0; pulse: score2 (base) 
df = sa_noise_df[sa_noise_df["Site"]=="W50"]
score_col = 'score0'

(ggplot(df, aes(x = 'date', y = score_col, color = 'Lcapito', alpha = 'Lcapito'))+ 
       geom_point()+ 
        labs(x  = "Date", y = "RIBBIT score", title = "RIBBIT scores")+ 
        #facet_wrap("pond")+
        geom_hline(yintercept = 72, color = 'gray', linetype = 'dashed')+
        theme_bw()+ 
        theme(axis_text_x = element_text(angle = 90)))
# Out:
# <ggplot: (307841077)>

# %%
#  Histogram of ribbit scores

cutoff = 72
df = sa_noise_df#[sa_noise_df["pond"]=="9a"]
score_col = 'score0'
print("Total number of files: " + str(len(df)))
print("Number of files with RIBBIT score above cutoff: " + str(len(df[df[score_col]>cutoff])
))

(ggplot(df)+
aes(x = score_col, fill = "Lcapito")+
geom_histogram(bins = 40)+ geom_vline(xintercept = cutoff, linetype = "dashed", color = "blue")+
labs(title = "Model 1", x = "RIBBIT score", y = "Number of files")+ 
theme_bw())
# Out:
# Total number of files: 2564
# Number of files with RIBBIT score above cutoff: 104
# <ggplot: (305005953)>

# %%
for i in sa_noise_df["Site"].unique():
    df = sa_noise_df[sa_noise_df["Site"]==i]
    print("Wetland: " + i)
    print("Total number of files: " + str(len(df)))
# Out:
# Wetland: W42
# Total number of files: 194
# Wetland: W51
# Total number of files: 267
# Wetland: W15
# Total number of files: 225
# Wetland: W46
# Total number of files: 219
# Wetland: W40
# Total number of files: 107
# Wetland: W04
# Total number of files: 98
# Wetland: W53
# Total number of files: 301
# Wetland: W29
# Total number of files: 112
# Wetland: W03
# Total number of files: 134
# Wetland: W41
# Total number of files: 227
# Wetland: W35
# Total number of files: 111
# Wetland: W52
# Total number of files: 167
# Wetland: W58
# Total number of files: 184
# Wetland: W32
# Total number of files: 115
# Wetland: W55
# Total number of files: 226
# Wetland: W00
# Total number of files: 258
# Wetland: W96
# Total number of files: 115
# Wetland: W43
# Total number of files: 192
# Wetland: W68
# Total number of files: 95
# Wetland: W02
# Total number of files: 137
# Wetland: W37
# Total number of files: 96
# Wetland: W28
# Total number of files: 141
# Wetland: W36
# ...

# %%
# calculate prescision/recall for a model 


def calc_accuracy(df, cutoffs, score_col = 'score'):    
    accuracy = pd.DataFrame()
    accuracy.index = list(cutoffs)
    accuracy['precision'] = ''
    accuracy['recall'] = ''

    for c in cutoffs: 
        accuracy['precision'][c] = len(df[(df['Lcapito']==1) & (df[score_col]>c)])/len(df[df[score_col]>c])*100
        accuracy['recall'][c] = len(df[(df['Lcapito'] == 1) & (df[score_col]>c)])/len(df[(df['Lcapito'] == 1)])*100

    return accuracy

# %%
#ggplot version of precision/recall (ugly right now)

#df = sa_window_df
#score_col = 'score0'
#cutoffs = range(0,200)
#ich_accuracy_df = calc_accuracy(df, cutoffs, score_col = score_col) 

#(ggplot(ich_accuracy_df, aes(x = 'precision', y = 'recall'))+ 
#       geom_point(alpha = 0.5)+ 
#        )

# %%
sa_window_df2[0:2100]
# Out:
#                                               file_path  Unnamed: 0  year  \
# 0     /Volumes/Expansion/Frog Call Project/Calling D...           0  2015
# 1     /Volumes/Expansion/Frog Call Project/Calling D...           1  2015
# 2     /Volumes/Expansion/Frog Call Project/Calling D...           2  2015
# 3     /Volumes/Expansion/Frog Call Project/Calling D...           3  2015
# 4     /Volumes/Expansion/Frog Call Project/Calling D...           4  2015
# ...                                                 ...         ...   ...
# 2095  /Volumes/Expansion/Frog Call Project/Calling D...        4665  2015
# 2096  /Volumes/Expansion/Frog Call Project/Calling D...        4666  2015
# 2097  /Volumes/Expansion/Frog Call Project/Calling D...        4667  2015
# 2098  /Volumes/Expansion/Frog Call Project/Calling D...        4668  2015
# 2099  /Volumes/Expansion/Frog Call Project/Calling D...        4669  2015
#
#      pond                date Lcapito  score0  time_stamp0
# ...

# %%
# plot precision/recall for several values of one parameter of SA 

cutoffs = range(0,150)

df = sa_window_df2
cutoffs = range(0,150)
ich_accuracy0 = calc_accuracy(df, cutoffs, score_col = 'score0')
cutoffs = range(0,200)
ich_accuracy1 = calc_accuracy(df, cutoffs, score_col = "score1")
ich_accuracy_noise = calc_accuracy(sa_noise_df, cutoffs, score_col = "score0") # base vals
ich_accuracy_base = calc_accuracy(sa_base_df, cutoffs, score_col = "score") # base vals

#pulse, noise, signal, duration, optimal guess


# best: 
# pulse: param1 (by a tad)
# noise: both better, param0 slightly better at first but param1 overtakes  - try 1100-1300 band? 
# signal: both better, param0/param2  better at first but param1 better later - probably go with param0/2 
# duration: pretty similar


fig, ax = plt.subplots()  # a figure with a single Axes
ax.scatter(ich_accuracy0['precision'],ich_accuracy0['recall'], alpha = 0.5, label = "0")
ax.scatter(ich_accuracy1['precision'],ich_accuracy1['recall'], alpha = 0.5, label = "1") 

#ax.scatter(ich_accuracy2['precision'],ich_accuracy2['recall'], alpha = 0.5, label = "2")
ax.scatter(ich_accuracy_noise['precision'],ich_accuracy_noise['recall'], alpha = 0.5, label = "noise")
ax.scatter(ich_accuracy_base['precision'],ich_accuracy_base['recall'], alpha = 0.5, label = "base")
ax.legend()
ax.set_xlabel('precision')
ax.set_ylabel('recall') 
#ax.set_xlim(0,40)
#ax.set_title('RIBBIT scores')
# Out:
# Text(0, 0.5, 'recall')

# %%
# calculate precision recall: compare best parameter values for each parameter from the SAs
cutoffs = range(0,200)

ich_accuracy0 = calc_accuracy(sa_optimal_guess_df, cutoffs, score_col = 'score0')
ich_accuracy1 = calc_accuracy(sa_noise_df, cutoffs, score_col = "score0")
ich_accuracy2 = calc_accuracy(sa_signal_df, cutoffs, score_col = "score2")
ich_accuracy3 = calc_accuracy(sa_duration_df, cutoffs, score_col = "score0")
ich_accuracy4 = calc_accuracy(sa_pulse_df, cutoffs, score_col = "score1")
ich_accuracy5 = calc_accuracy(sa_optimal_guess_df2, cutoffs, score_col = "score0") 
ich_accuracy6 = calc_accuracy(sa_window_df, cutoffs, score_col = "score1") 
ich_accuracy_base = calc_accuracy(sa_pulse_df, cutoffs, score_col = "score2") # base vals
#ich_accuracy0 = calc_accuracy(sa_pulse_df[sa_pulse_df["pond"]!="7a"], cutoffs)

#pulse, noise, signal, duration, optimal guess


# plot precision and recall for pulse rate sa - looks like [12,28] is best of the options 

# best: 
# pulse: param1 (by a tad)
# noise: both better, param0 slightly better at first but param1 overtakes  - try 1100-1300 band? 
# signal: both better, param0/param2  better at first but param1 better later - probably go with param0/2 
# duration: pretty similar
# optimal guess:

# %%
# plot to compare best parameter values for each parameter tested in SA

fig, ax = plt.subplots()  # a figure with a single Axes
ax.scatter(ich_accuracy0['precision'],ich_accuracy0['recall'], alpha = 0.5, label = "optimal guess")
ax.scatter(ich_accuracy1['precision'],ich_accuracy1['recall'], alpha = 0.5, label = "noise") 
ax.scatter(ich_accuracy2['precision'],ich_accuracy2['recall'], alpha = 0.5, label = "signal")
#ax.scatter(ich_accuracy3['precision'],ich_accuracy3['recall'], alpha = 0.5, label = "duration")
#ax.scatter(ich_accuracy4['precision'],ich_accuracy4['recall'], alpha = 0.5, label = "pulse")
ax.scatter(ich_accuracy5['precision'],ich_accuracy5['recall'], alpha = 0.5, label = "optimal guess2")
ax.scatter(ich_accuracy6['precision'],ich_accuracy6['recall'], alpha = 0.5, label = "window samples")
#ax.scatter(ich_accuracy_base['precision'],ich_accuracy_base['recall'], alpha = 0.5, label = "base")
ax.legend()
ax.set_xlabel('precision')
ax.set_ylabel('recall') 
ax.set_xlim(2,100)
ax.set_ylim(10,102)
#ax.set_title('RIBBIT scores')
# Out:
# (10.0, 102.0)

# %%
# comparing RIBBIT scores for individual files to see if some versions of a model do better with different files
# appears noise and signal bands are pretty similar, but changing window samples changes results a little more (still not a lot)

df = sa_noise_df
pond = '7a'
df['Lcapito'] = df['Lcapito'].astype('category') 
(ggplot(df[df['Lcapito']==1][df['pond']==pond])+
aes(x = 'date', y = 'score0', color = 'pond')+
geom_point())
# Out:
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/plotnine/guides/guide_legend.py:308: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# <ggplot: (321199077)>

# %%
# comparing RIBBIT scores for individual files to see if some versions of a model do better with different files
# appears noise and signal bands are pretty similar, but changing window samples changes results a little more (still not a lot)

df = sa_window_df2
pond = '7a'
df['Lcapito'] = df['Lcapito'].astype('category') 
(ggplot(df[df['Lcapito']==1][df['pond']==pond])+
aes(x = 'date', y = 'score0', color = 'pond')+
geom_point())
# Out:
# <ggplot: (323040565)>

# %% [markdown]
# ## Looking at files where the model is doing poorly

# %%
# Look at files with lowest RIBBIT scores that have documented Lcapito 
ich_tr_df[ich_tr_df['Lcapito'] == 1].sort_values(by = "score", ascending = True) 

#look at files with high RIBBIT scores with no documented Lcapito
ich_tr_df[ich_tr_df['Lcapito'] == 0].sort_values(by = "score", ascending = False).head(10) 


# List all false negatives in df
#df = ich_verified_files_df
df = ich_tr_df
false_neg = df[(df['Lcapito'] == 1) & (df['score']<100)].sort_values(by = ["pond", "date"], ascending = True) #Problem poin

print("Number of false negatives: " + str(len(false_neg)))
#false_neg


# List "obvious" false positives in df
#df = ich_verified_files_df
df = ich_tr_df
false_pos = df[(df['Lcapito'] == 0) & (df['score']>=100)].sort_values(by = ["pond", "date"], ascending = True) # problem point 

print("Number of false positives: " + str(len(false_pos))) 
#false_pos


#print(sa_noise_df[sa_noise_df['Lcapito']==1].sort_values(by = 'score0', ascending = True).head(10)[['pond', 'date', 
#                                                       'Lcapito', 'score0', 'Unnamed: 0']].sort_values(by = ['pond', 'date']))

# %% [markdown]
# ## Plots for Jenn

# %% [markdown]
# ### Best model: noise band at [1100,1200]

# %%
#  Histogram of ribbit scores

cutoff = 70
print("Total number of files: " + str(len(sa_noise_df)))
print("Number of files with RIBBIT score above cutoff: " + str(len(sa_noise_df[sa_noise_df['score0']>cutoff])
))

(ggplot(sa_noise_df)+
aes(x = 'score0')+
geom_histogram()+ geom_vline(xintercept = cutoff, linetype = "dashed", color = "blue")+
labs(title = "Model 1", x = "RIBBIT score", y = "Number of files")+ 
theme_bw())
# Out:
# Total number of files: 2564
# Number of files with RIBBIT score above cutoff: 116
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/plotnine/stats/binning.py:35: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 197'. Pick better value with 'binwidth'.
# ...

# %%
# scatter plot of ribbit scores 

df = sa_noise_df#sa_optimal_guess_df 
score_col = 'score0'
df['Lcapito'] = df['Lcapito'].astype('category')

(ggplot(df, aes(x = 'date', y = score_col, color = 'Lcapito', alpha = 'Lcapito'))+ 
       geom_point()+ 
        labs(x  = "Date", y = "RIBBIT score", title = "Model 1")+ 
        theme_bw()+ 
        theme(axis_text_x = element_text(angle = 90))+
        geom_hline(yintercept = 72, color = 'gray', linetype = 'dashed'))
# Out:
# <ggplot: (305250821)>

# %% [markdown]
# ### Model 2: "Optimal guess" model

# %%
# Histogram of ribbit scores 

cutoff = 72
print("Total number of files: " + str(len(sa_optimal_guess_df2)))
print("Number of files with RIBBIT score above cutoff: " + str(len(sa_optimal_guess_df2[sa_optimal_guess_df2['score0']>cutoff])
))

(ggplot(sa_optimal_guess_df2)+
aes(x = 'score0')+
geom_histogram()+ geom_vline(xintercept = cutoff, linetype = "dashed", color = "blue")+
labs(title = "Model 2", x = "RIBBIT score", y = "Number of files")+
theme_bw())
# Out:
# Total number of files: 2564
# Number of files with RIBBIT score above cutoff: 140
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/plotnine/stats/binning.py:35: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 279'. Pick better value with 'binwidth'.
# ...

# %%
# scatter plot of ribbit scores 

df = sa_optimal_guess_df 
score_col = 'score0'
df['Lcapito'] = df['Lcapito'].astype('category')

(ggplot(df, aes(x = 'date', y = score_col, color = 'Lcapito', alpha = 'Lcapito'))+ 
       geom_point()+ 
        labs(x  = "Date", y = "RIBBIT score", title = "Model 2")+ 
        theme_bw()+ 
        theme(axis_text_x = element_text(angle = 90))+
        geom_hline(yintercept = 72, color = 'gray', linetype = 'dashed'))
# Out:
# <ggplot: (319492645)>

# %% [markdown]
# ### Judging accuracy of models 1 & 2

# %%
cutoffs = range(0,200)
ich_accuracy0 = calc_accuracy(sa_optimal_guess_df, cutoffs, score_col = 'score0')
ich_accuracy1 = calc_accuracy(sa_noise_df, cutoffs, score_col = "score0")
ich_accuracy_base = calc_accuracy(sa_base_df, cutoffs, score_col = "score")

print(ich_accuracy0[72:73])
print(ich_accuracy1[70:71])
# Out:
#    precision recall
# 72     19.11  76.79
#    precision recall
# 70     34.48  71.43

# %%
# plot of precision vs recall 

fig, ax = plt.subplots()  # a figure with a single Axes
ax.scatter(ich_accuracy1['precision'],ich_accuracy1['recall'], alpha = 0.5, label = "Model 1") # "noise"
ax.scatter(ich_accuracy0['precision'],ich_accuracy0['recall'], alpha = 0.5, label = "Model 2") #"optimal guess"
ax.scatter(ich_accuracy_base['precision'],ich_accuracy_base['recall'], alpha = 0.5, label = "Base model") #"base"
plt.plot(19.11, 76.79, marker="*", markersize=15, markeredgecolor="red", markerfacecolor="red")
plt.plot(34.48, 71.43, marker="*", markersize=15, markeredgecolor="blue", markerfacecolor="blue")
ax.legend()
ax.set_xlabel('Precision')
ax.set_ylabel('Recall') 
ax.set_title('Model accuracy for various cutoff values') 
ax.set_xlim(2,100)
ax.set_ylim(10,102)
#ax.set_title('RIBBIT scores')
# Out:
# (10.0, 102.0)

# %% [markdown]
# ## Look at individual file to see why model isn't doing well for it

# %%
# Look at individual file

#get the audio file path
audio_path = ich_tr_df['file_path'][2734]
audio = Audio.from_file(audio_path)

#make the spectrogram
spec = Spectrogram.from_audio(audio.from_file(audio_path).trim(0,5))

#show the spectrogram
print('spectrogram')
spec.plot()

#run RIBBIT
# minimum and maximum rate of pulsing (pulses per second) to search for
pulse_rate_range = [14,28] 

# look for a vocalization in the range of 600-800 Hz
signal_band = [600,800]

# subtract the amplitude signal from these frequency ranges
noise_bands = [[150,200], [1500,1600]]

#divides the signal into segments this many seconds long, analyzes each independently
clip_duration = 1 #seconds
clip_overlap = 0.5 #seconds
score_df =  ribbit(
                    spec,
                    pulse_rate_range=pulse_rate_range,
                    signal_band=signal_band,
                    clip_duration=clip_duration,
                    noise_bands=noise_bands,
                    plot=False
)

# plot the score vs time of each window
plt.scatter(score_df['start_time'],score_df['score'])
plt.xlabel('window start time (sec)')
plt.ylabel('RIBBIT score')
plt.title('RIBBIT scores for 10 second file with Great Plains Toad at the beginning')
# Out:
# spectrogram
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 62, using nperseg = 62
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 63, using nperseg = 63
# Text(0.5, 1.0, 'RIBBIT scores for 10 second file with Great Plains Toad at the beginning')

# %%
ich_tr_df['file_path'][2734]
glob(ich_tr_df['file_path'][2734])
# Out:
# ['/Volumes/Expansion/Frog Call Project/Calling Data/Frog Calls/ichaway_2015/10a/20150314_201500.wav']

# %% [markdown]
# ## Function to get top ribbit scores for ponds/months/etc.

# %%
# get list of audio files with top ribbit scores
#
# input: 
# df - data frame with ribbit scores 
# n - number of files per group (e.g. n = 5 gets top 5 ribbit scores per group)
# min_score - minimum ribbit score needed for file to be included 
# (e.g. if you want all files above a ribbit score of 50, min_score = 50 and n = 999999999999)
# group_col - the name of the column with the labels grouping our files 
#            (e.g. "pond" for sandhills or "Site" for ichaway wetlands)
#             if group_col = "", just takes overall top scores 
# groups - list of labels of the different categories we want to split the data into - e.g. "range(398, 403)"" for sandhills ponds or "ich_wetlands" for ichaway wetlands
# t_unit - unit for how often we want the top scores (options: D, W, M, Y - day, week, month, year)
# NOT IMPLEMENTED!!! t_n - number for how often we want the top scores 
# NOT IMPLEMENTED!!! start - if "first", start with the first file, else `start` should be a date 
# NOT IMPLEMENTED!!! end - if "last", end with the last file, else `start` should be a date 
# (e.g. if n = 5, ponds = range(398, 403), t_unit = week and t_n = 3, we want the top 5 scores for every three weeks for all of the ponds )
#
# out: 
# dataframe with top `n` files for `ponds` for every `t_n` `t_unit` beginning with `start` and finishing with `end`
def get_top_rs(df, n = 5, min_score = 0, group_col = '', groups = range(398, 403), t_unit = "Y", t_n = 1, start = "first", end = "last", score_col = "score", time_stamp_col = "time_stamp"):
    
    rs_df = df[df['score_col']>min_score] # only keep files with scores above the minimum allowed ribbit score
    
    if group_col == '': # if we don't want to group the data - just want overall top scores
        rs_df['date_group'] = rs_df['date'].dt.to_period(t_unit)


        out_df = rs_df.sort_values(by=score_col,ascending=False).groupby(by = ['date_group']).head(n).sort_values(by = ['year', 'date_group'])


        # organize the df
        out_df['file_path'] = out_df['file_path'].str.slice(61) # simplify file path to not have beginning crap
        out_df = out_df.reindex(columns = ['Lcapito', 'date_group', score_col, time_stamp_col, 'file_path']) #order columns 

    else: # if we want to group the data 
        rs_df = rs_df[rs_df[group_col].isin(groups)]
        rs_df['date_group'] = rs_df['date'].dt.to_period(t_unit)


        out_df = rs_df.sort_values(by=score_col,ascending=False).groupby(by = [group_col, 'date_group']).head(n).sort_values(by = [group_col, 'year', 'date_group'])


        # organize the df
        out_df['file_path'] = out_df['file_path'].str.slice(61) # simplify file path to not have beginning crap
        out_df = out_df.reindex(columns = ['Lcapito', group_col, 'date_group', score_col, time_stamp_col, 'file_path']) #order columns 

    return out_df

# %%
sa_noise_df
# Out:
#                                               file_path  Unnamed: 0  year  \
# 0     /Volumes/Expansion/Frog Call Project/Calling D...        1060  2015
# 1     /Volumes/Expansion/Frog Call Project/Calling D...        1061  2015
# 2     /Volumes/Expansion/Frog Call Project/Calling D...        1059  2015
# 3     /Volumes/Expansion/Frog Call Project/Calling D...        4605  2015
# 4     /Volumes/Expansion/Frog Call Project/Calling D...        1063  2015
# ...                                                 ...         ...   ...
# 2559  /Volumes/Expansion/Frog Call Project/Calling D...        1058  2015
# 2560  /Volumes/Expansion/Frog Call Project/Calling D...         694  2015
# 2561  /Volumes/Expansion/Frog Call Project/Calling D...        1378  2015
# 2562  /Volumes/Expansion/Frog Call Project/Calling D...         702  2015
# 2563  /Volumes/Expansion/Frog Call Project/Calling D...         703  2015
#
#      pond                date Lcapito  score0  time_stamp0   score1  \
# ...

# %%
temp  = ['a', 'b']
print(temp)
temp.append()
print(temp)
# Out:
# ['a', 'b']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fx/n9nq8hjd5w7f5ymx00xgfcdh0000gn/T/ipykernel_2719/1406255876.py in <module>
#       1 temp  = ['a', 'b']
#       2 print(temp)
# ----> 3 temp.append()
#       4 print(temp)
#
# TypeError: append() takes exactly one argument (0 given)

# %%
sa_noise_df.groupby(by = ['year'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/fx/n9nq8hjd5w7f5ymx00xgfcdh0000gn/T/ipykernel_2719/643380823.py in <module>
# ----> 1 sa_noise_df.groupby(by = ['year', ''])
#
# ~/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# ~/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# ...

# %%
# example of using "get top rs"

#get top ichaway scores by logger for each month 
all_ich_loggers = ['1a','2a','3a', '4a', '5a', '6a', '7a', '8a', '9a', '10a']
temp = get_top_rs(sa_noise_df, n = 5, groups = ['8a', '9a'], t_unit = 'M', score_col = 'score0', time_stamp_col = 'time_stamp0')

#print(temp)

# get top ichaway scores by wetland 
temp = get_top_rs(sa_noise_df, n = 5, group_col = "Site", groups = ich_wetlands, t_unit = 'M', score_col = 'score0', time_stamp_col = 'time_stamp0')

print(temp)
# Out:
#      Lcapito Site date_group  score0  time_stamp0  \
# 2346     0.0  W00    2015-02   60.51        189.0
# 2345     0.0  W00    2015-02   60.51        189.0
# 980      0.0  W00    2015-02   57.83        269.0
# 979      0.0  W00    2015-02   57.83        269.0
# 978      0.0  W00    2015-02   57.83        269.0
# ...      ...  ...        ...     ...          ...
# 3642     0.0  W96    2015-05   59.12        112.0
# 1929     0.0  W96    2015-05   57.13         92.5
# 3241     0.0  W96    2015-05   54.81        171.5
# 3687     0.0  W96    2015-05   44.06        160.0
# 3180     0.0  W96    2015-05   41.63        168.5
#
#                                 file_path
# 2346  ichaway_2015/7a/20150216_225600.wav
# 2345  ichaway_2015/7a/20150216_225600.wav
# 980   ichaway_2015/7a/20150216_205600.wav
# 979   ichaway_2015/7a/20150216_205600.wav
# 978   ichaway_2015/7a/20150216_205600.wav
# ...                                   ...
# 3642  ichaway_2015/3a/20150509_005200.wav
# ...

# %%
# plot ichaway ribbit scores
def plot_rs(plot_df, score_col = 'score', cutoff = -1):
    plot_df1 = plot_df[plot_df['Lcapito'] == 1]
    plot_df0 = plot_df[plot_df['Lcapito'] == 0]

    fig, ax = plt.subplots()  # a figure with a single Axes
    ax.scatter(plot_df0['date'],plot_df0[score_col], alpha = 0.5)
    ax.scatter(plot_df1['date'],plot_df1[score_col], alpha = 0.5)
    #plt.ylim(0, 100)
    if cutoff > 0: 
        ax.hlines(y = [cutoff], xmin = plot_df.date.min(), 
                    xmax = plot_df.date.max(),
                    colors = 'r', linestyles = '--')
    ax.set_xlabel('date')
    ax.set_ylabel('RIBBIT score') 
    ax.set_title('RIBBIT scores')
