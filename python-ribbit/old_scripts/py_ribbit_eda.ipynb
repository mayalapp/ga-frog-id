# %%
## OpenSoundscape RIBBIT tutorial
# http://opensoundscape.org/en/latest/tutorials/RIBBIT_pulse_rate_demo.html

# %% [markdown]
# ## Setup

# %%
# suppress warnings
import warnings
warnings.simplefilter('ignore')

#import packages
import numpy as np
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt
import subprocess

#local imports from opensoundscape
from opensoundscape.audio import Audio
from opensoundscape.spectrogram import Spectrogram
from opensoundscape.ribbit import ribbit

# create big visuals
plt.rcParams['figure.figsize']=[15,8]
pd.set_option('display.precision', 2)

# %%
## Load audio clip from file

# %%
audio_path = np.sort(glob('./test_gopher_audio/400_20170305_223800_Lcapito.wav'))[0]
print(audio_path)
#load the audio file into an OpenSoundscape Audio object
audio = Audio.from_file(audio_path)

#trim the audio to cut out person
audio = audio.trim(53,55)

#create a Spectrogram object
spectrogram = Spectrogram.from_audio(audio) #, window_samples = 300

# view spectrogram 
spectrogram.plot()
# Out:
# ./test_gopher_audio/400_20170305_223800_Lcapito.wav

# %% [markdown]
# ## Set parameters

# %%
# minimum and maximum rate of pulsing (pulses per second) to search for
pulse_rate_range = [16,28]

# look for a vocalization in the range of 1000-2000 Hz
signal_band = [600,800]

# subtract the amplitude signal from these frequency ranges
# noise_bands = [ [0,200], [1500,2000]]

#divides the signal into segments this many seconds long, analyzes each independently
clip_duration = 0.5 #seconds
clip_overlap = 0 #seconds

#if True, it will show the power spectrum plot for each audio segment
show_plots = True

# %% [markdown]
# ## Test sample audios

# %%
# test sample gopher call (positive test)
audio_path = glob('./test_gopher_audio/gopher_sample.wav')[0]
print("Gopher test file: ", audio_path)


#make the spectrogram
spec = Spectrogram.from_audio(audio.from_file(audio_path))#.trim(53,55))

#run RIBBIT
score_df =  ribbit(
                    spec,
                    pulse_rate_range=pulse_rate_range,
                    signal_band=signal_band,
                    clip_duration=clip_duration,
                    #noise_bands=noise_bands,
                    plot=False)
print("Gopher call Ribbit score: ", max(score_df.score))


# test sample ornate chorus frog call (negative test)
audio_path = glob('./test_gopher_audio/ornate_chorus_frog_sample.wav')[0]
print("\nChorus frog test file: ", audio_path)

#make the spectrogram
spec = Spectrogram.from_audio(audio.from_file(audio_path))

#run RIBBIT
score_df =  ribbit(
                    spec,
                    pulse_rate_range=pulse_rate_range,
                    signal_band=signal_band,
                    clip_duration=clip_duration,
                    #noise_bands=noise_bands,
                    plot=False)


print("Chorus frog Ribbit score (should be lower): ", max(score_df.score))
# Out:
# Gopher test file:  ./test_gopher_audio/gopher_sample.wav
# Gopher call sample Ribbit score:  0.0127293300161339
#
# Chorus frog test file:  ./test_gopher_audio/ornate_chorus_frog_sample.wav
# Ornage chorus frog sample Ribbit score (should be lower):  0.00024338360927002051
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 86, using nperseg = 86
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 87, using nperseg = 87
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 86, using nperseg = 86
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 87, using nperseg = 87
#   .format(nperseg, input_length))

# %%
audio_path = np.sort(glob('./test_gopher_audio/400_20170304_223700_Lcapito.wav'))[0]

print(audio_path)

#make the spectrogram
spec = Spectrogram.from_audio(audio.from_file(audio_path))#.trim(53,55))

#run RIBBIT
score_df =  ribbit(
                    spec,
                    pulse_rate_range=pulse_rate_range,
                    signal_band=signal_band,
                    clip_duration=clip_duration,
                    #noise_bands=noise_bands,
                    plot=False)
    

# plot the score vs time of each window
plt.scatter(score_df['start_time'],score_df['score'])
plt.xlabel('window start time (sec)')
plt.ylabel('RIBBIT score')
plt.title('RIBBIT scores')

score_df.sort_values(by='score',ascending=False).head(20)
# Out:
# ./test_gopher_audio/400_20170304_223700_Lcapito.wav
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 46, using nperseg = 46
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 47, using nperseg = 47
#   .format(nperseg, input_length))
# spectrogram
#      start_time  end_time     score
# 352       176.0     176.5  4.11e-03
# 351       175.5     176.0  3.41e-03
# 302       151.0     151.5  3.34e-03
# 108        54.0      54.5  2.82e-03
# 338       169.0     169.5  2.74e-03
# ..          ...       ...       ...
# 441       220.5     221.0  6.81e-05
# 136        68.0      68.5  6.78e-05
# 463       231.5     232.0  6.11e-05
# 183        91.5      92.0  5.32e-05
# 319       159.5     160.0  5.00e-05
#
# [600 rows x 3 columns]

# %%
## analyzing set of files

# %%
# set up a dataframe for storing files' scores and labels
df = pd.DataFrame(index = glob('./test_gopher_audio/*'),columns=['score','label'])

# label is 1 if the file contains a Great Plains Toad vocalization, and 0 if it does not
df['label'] = [1 if 'Lcapito' in f else 0 for f in df.index]

# calculate RIBBIT scores
for path in df.index:

    #make the spectrogram
    spec = Spectrogram.from_audio(audio.from_file(path))

    #run RIBBIT
    score_df =  ribbit(
                        spec,
                        pulse_rate_range=pulse_rate_range,
                        signal_band=signal_band,
                        clip_duration=clip_duration,
                        #noise_bands=noise_bands,
                        plot=False)

    # use the maximum RIBBIT score from any window as the score for this file
    # multiply the score by 10,000 to make it easier to read
    df.at[path,'score'] = max(score_df.score) * 10000

print("Files sorted by score, from highest to lowest:")
df.sort_values(by='score',ascending=False)
# Out:
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 172, using nperseg = 172
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 173, using nperseg = 173
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 172, using nperseg = 172
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 173, using nperseg = 173
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 172, using nperseg = 172
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 173, using nperseg = 173
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# Files sorted by score, from highest to lowest:
#                                                      score  label
# ./test_gopher_audio/gopher_sample.wav               230.68      0
# ./test_gopher_audio/400_20170303_193600_Lcapito...  119.95      1
# ./test_gopher_audio/400_20170305_223800_Lcapito...   96.95      1
# ./test_gopher_audio/FLSH-402_0+1_20170308_01390...   79.23      0
# ./test_gopher_audio/pops2.mp3                        63.76      0
# ./test_gopher_audio/pops1.mp3                        59.37      0
# ./test_gopher_audio/400_20170304_223700_Lcapito...   54.13      1
# ./test_gopher_audio/400_20170308_234000_Lcapito...   52.21      1
# ./test_gopher_audio/FLSH-402_0+1_20170308_21400...    34.5      0
# ./test_gopher_audio/399_20170304_193700_possLca...   28.67      1
# ./test_gopher_audio/FLSH-402_0+1_20170308_02390...   20.95      0
# ./test_gopher_audio/399_20170305_203800_possLca...   14.83      1
# ./test_gopher_audio/FLSH-402_0+1_20170307_23390...   14.07      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_00390...   14.05      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_20400...    11.3      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_18400...   11.23      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_19400...   11.15      0
# ./test_gopher_audio/gpt2.mp3                          4.71      0
# ./test_gopher_audio/gpt0.mp3                          4.53      0
# ./test_gopher_audio/negative9.mp3                      4.3      0
# ./test_gopher_audio/gpt1.mp3                          4.19      0
# ./test_gopher_audio/water.mp3                         3.87      0
# ./test_gopher_audio/negative8.mp3                     3.71      0
# ./test_gopher_audio/negative4.mp3                     3.38      0
# ./test_gopher_audio/negative1.mp3                     3.11      0
# ./test_gopher_audio/negative7.mp3                      3.1      0
# ./test_gopher_audio/negative5.mp3                     3.02      0
# ./test_gopher_audio/gpt3.mp3                          2.99      0
# ./test_gopher_audio/negative2.mp3                     2.82      0
# ./test_gopher_audio/gpt4.mp3                          2.46      0
# ./test_gopher_audio/negative3.mp3                     2.45      0
# ./test_gopher_audio/negative6.mp3                     2.44      0
# ./test_gopher_audio/silent.mp3                        1.99      0
# ./test_gopher_audio/ornate_chorus_frog_sample.wav     1.58      0

# %%
# set up a dataframe for storing files' scores and labels
df = pd.DataFrame(index = glob('./test_gopher_audio/*'),columns=['score','label'])

# label is 1 if the file contains a Great Plains Toad vocalization, and 0 if it does not
df['label'] = [1 if 'Lcapito' in f else 0 for f in df.index]

noise_bands = [[0,10]]

# calculate RIBBIT scores
for path in df.index:

    #make the spectrogram
    spec = Spectrogram.from_audio(audio.from_file(path))

    #run RIBBIT
    score_df =  ribbit(
                        spec,
                        pulse_rate_range=pulse_rate_range,
                        signal_band=signal_band,
                        clip_duration=clip_duration,
                        noise_bands=noise_bands,
                        plot=False)

    # use the maximum RIBBIT score from any window as the score for this file
    # multiply the score by 10,000 to make it easier to read
    df.at[path,'score'] = max(score_df.score) * 10000

print("Files sorted by score, from highest to lowest:")
df.sort_values(by='score',ascending=False)
# Out:
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 172, using nperseg = 172
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 173, using nperseg = 173
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 172, using nperseg = 172
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 173, using nperseg = 173
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 172, using nperseg = 172
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 173, using nperseg = 173
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 187, using nperseg = 187
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 188, using nperseg = 188
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 93, using nperseg = 93
#   .format(nperseg, input_length))
# /Users/mayalapp/opt/anaconda3/envs/opensoundscape060/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 94, using nperseg = 94
#   .format(nperseg, input_length))
# Files sorted by score, from highest to lowest:
#                                                       score  label
# ./test_gopher_audio/FLSH-402_0+1_20170308_18400...  3236.96      0
# ./test_gopher_audio/gopher_sample.wav               3121.07      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_19400...  2983.75      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_02390...   2683.4      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_21400...  2141.58      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_01390...  2084.94      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_00390...   2012.3      0
# ./test_gopher_audio/FLSH-402_0+1_20170308_20400...  1989.94      0
# ./test_gopher_audio/400_20170303_193600_Lcapito...  1942.37      1
# ./test_gopher_audio/FLSH-402_0+1_20170307_23390...  1744.89      0
# ./test_gopher_audio/399_20170305_203800_possLca...  1743.63      1
# ./test_gopher_audio/400_20170308_234000_Lcapito...  1702.67      1
# ./test_gopher_audio/400_20170305_223800_Lcapito...  1695.21      1
# ./test_gopher_audio/400_20170304_223700_Lcapito...  1637.82      1
# ./test_gopher_audio/399_20170304_193700_possLca...  1596.08      1
# ./test_gopher_audio/ornate_chorus_frog_sample.wav   1140.92      0
# ./test_gopher_audio/negative9.mp3                   1120.74      0
# ./test_gopher_audio/pops2.mp3                        875.39      0
# ./test_gopher_audio/pops1.mp3                        870.29      0
# ./test_gopher_audio/gpt0.mp3                         748.36      0
# ./test_gopher_audio/negative7.mp3                    742.23      0
# ./test_gopher_audio/gpt2.mp3                          620.7      0
# ./test_gopher_audio/negative1.mp3                    561.53      0
# ./test_gopher_audio/gpt1.mp3                         512.43      0
# ./test_gopher_audio/gpt4.mp3                         454.81      0
# ./test_gopher_audio/gpt3.mp3                         446.71      0
# ./test_gopher_audio/negative4.mp3                    438.96      0
# ./test_gopher_audio/water.mp3                         389.8      0
# ./test_gopher_audio/negative5.mp3                    385.58      0
# ./test_gopher_audio/negative8.mp3                    339.29      0
# ./test_gopher_audio/negative6.mp3                    327.13      0
# ./test_gopher_audio/negative2.mp3                    256.83      0
# ./test_gopher_audio/negative3.mp3                     239.7      0
# ./test_gopher_audio/silent.mp3                         3.73      0
